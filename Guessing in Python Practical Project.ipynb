# %%
import random

random_number = random.randint(1,10)
print(random_numbe3r)
# Out:
# 4

# %%
import random

random_number = random.randint(1,10)

guess = input("Pick a number between 1 - 10: ")
guess = int(guess)
if guess == random_number:
    print("CORRECT!")
elif guess < random_number:
    print("TOO LOW!")
else:
    print("TOO HIGH!")
print(random_number)
# Out:
# Pick a number between 1 - 10: 6
# CORRECT!
# 6

# %% [markdown]
# import random
#
# random_number = random.randint(1,10)
#
# guess = input("Pick a number between 1 - 10: ")
# guess = int(guess)
# if guess == random_number:
#     print("CORRECT!")
# elif guess < random_number:
#     print("TOO LOW!")
# else:
#     print("TOO HIGH!")
# print(random_number)

# %%
import random

random_number = random.randint(1,10)
while guess != random_number:
    guess = input("Pick a number between 1 - 10: ")
    guess = int(guess)
    if guess < random_number:
        print("TOO LOW!")
    elif guess > random_number:
        print("TOO HIGH!")
    else:
        print("YOU WON!!!")

        print(random_number)
# Out:
# Pick a number between 1 - 10: 3
# TOO LOW!
# Pick a number between 1 - 10: 3
# TOO LOW!
# Pick a number between 1 - 10: 3
# TOO LOW!
# Pick a number between 1 - 10: 3
# TOO LOW!
# Pick a number between 1 - 10: 3
# TOO LOW!
# Pick a number between 1 - 10: 3
# TOO LOW!
# Pick a number between 1 - 10: 3
# TOO LOW!
# Pick a number between 1 - 10: 3
# TOO LOW!
# Pick a number between 1 - 10: 3
# TOO LOW!
# Pick a number between 1 - 10: 3
# TOO LOW!
# Pick a number between 1 - 10: 3
# TOO LOW!
# Pick a number between 1 - 10: 3
# TOO LOW!
# Pick a number between 1 - 10: 3
# TOO LOW!
# Pick a number between 1 - 10: 3
# TOO LOW!
# Pick a number between 1 - 10: 3
# TOO LOW!
# Pick a number between 1 - 10: 3
# TOO LOW!
# Pick a number between 1 - 10: 9
# TOO HIGH!
# Pick a number between 1 - 10: 2
# TOO LOW!
# Pick a number between 1 - 10: 2
# TOO LOW!
# Pick a number between 1 - 10:  3
# TOO LOW!

# %%
import random
guess = ""
random_number = random.randint(1,10)
while guess != random_number:
    guess = input("Pick a number between 1 - 10: ")
    guess = int(guess)
    if guess < random_number:
        print("TOO LOW!")
    elif guess > random_number:
        print("TOO HIGH!")
    else:
        print("YOU WON!!!")

        print(random_number)
# Out:
# Pick a number between 1 - 10: 3
# TOO LOW!
# Pick a number between 1 - 10: 3
# TOO LOW!
# Pick a number between 1 - 10: 3
# TOO LOW!
# Pick a number between 1 - 10: 2
# TOO LOW!
# Pick a number between 1 - 10: 2
# TOO LOW!
# Pick a number between 1 - 10: 2
# TOO LOW!
# Pick a number between 1 - 10:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7148/722903805.py in <module>
#       4 while guess != random_number:
#       5     guess = input("Pick a number between 1 - 10: ")
# ----> 6     guess = int(guess)
#       7     if guess < random_number:
#       8         print("TOO LOW!")
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# ####

# %%
import random
guess = None
random_number = random.randint(1,10)
while guess != random_number:
    guess = input("Pick a number between 1 - 10: ")
    guess = int(guess)
    if guess < random_number:
        print("TOO LOW!")
    elif guess > random_number:
        print("TOO HIGH!")
    else:
        print("YOU WON!!!")

        print(random_number)
# Out:
# Pick a number between 1 - 10: 1
# YOU WON!!!
# 1

# %%
import random
guess =""
random_number != random.randint(1,10)
while True:
    guess = input("Pick a number btw 1 to 10: ")
    guess = int(guess)
    if guess < random_number:
        print("TOO LOW!")
    elif guess > random_number:
        print("TOO HIGH!")
    else:
        ("YOU WON!!!")
    play_again = input("Do you want to play again? (y/n) ")
    if play_again == "y":
        random_number != random.randint(1,10)
        guess = None
    else:
        print("Thank You!!!")
        
print(random_number)
# Out:
# Pick a number btw 1 to 10: 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7148/2082983992.py in <module>
#       5     guess = input("Pick a number btw 1 to 10: ")
#       6     guess = int(guess)
# ----> 7     if guess < random_number:
#       8         print("TOO LOW!")
#       9     elif guess > random_number:
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %% [markdown]
# #\

# %%
import random

random_number = random.randint(1,10)
guess = None

while True:
    guess = input("Pick a number btw 1 to 10: ")
    guess = int(guess)
    if guess < random_number:
        print("TOO LOW!")
    elif guess > random_number:
        print("TOO HIGH!")
    else:
        ("YOU WON!!!")
    play_again = input("Do you want to play again? (y/n) ")
    if play_again == "y":
        random_number != random.randint(1,10)
        guess = None
    else:
        print("Thank You!!!")
        break
        
print(random_number)
# Out:
# Pick a number btw 1 to 10: 3
# TOO LOW!
# Do you want to play again? (y/n) 3
# Thank You!!!
# 5

# %%
import random

random_number = random.randint(1,10)
guess = None

while True:
    guess = input("Pick a number btw 1 to 10: ")
    guess = int(guess)
    if guess < random_number:
        print("TOO LOW!")
    elif guess > random_number:
        print("TOO HIGH!")
    else:
        ("YOU WON!!!")
    play_again = input("Do you want to play again? (y/n) ")
    if play_again == "y":
        random_number = random.randint(1,10)
        guess = None
    else:
        print("Thank You!!!")
        break

# %%
import random

random_number = random.randint(1,10)
guess = None

while True:
    guess = input("Pick a number btw 1 to 10: ")
    guess = int(guess)
    if guess < random_number:
        print("TOO LOW!")
    elif guess > random_number:
        print("TOO HIGH!")
    else:
        ("YOU WON!!!")
    play_again = input("Do you want to play again? (y/n) ")
    if play_again == "y":
        random_number = random.randint(1,10)
        guess = None
    else:
        print("Thank You!!!")
        break
# Out:
# Pick a number btw 1 to 10: 1
# TOO LOW!
# Do you want to play again? (y/n) n
# Thank You!!!

# %%
import random

for time in range(3):
    print("red.....")
    print("blue.....")
    print("green....")

    AdMub = input("AdMub, play your card: ")
    rand_num = random.randint(0,2)
    if rand_num == 0:
        computer = "red"
    elif rand_num == 1:
        computer = "blue"
    else:
        computer = "green"
    print(f"computer plays {computer}")

    if AdMub == computer:
        print("Draws!") 
    elif AdMub == "red":
        if computer == "blue":
            print("AdMub wins!")
        else:
            print("AdMub wins!")
    elif AdMub == "blue":
        if computer == "green": 
            print("AdMub wins!") 
        else:
            print("computer wins!")
    elif AdMub == "green": 
        if computer == "blue": 
            print("computer wins!") 
        else: 
            print("computer wins!")
    else:
        print("Game-Over!")
# Out:
# red.....
# blue.....
# green....
# AdMub, play your card: yellow
# computer plays red
# Game-Over!
# red.....
# blue.....
# green....
# AdMub, play your card: blue
# computer plays green
# AdMub wins!
# red.....
# blue.....
# green....
# AdMub, play your card: red
# computer plays red
# Draws!

# %%
import random
AdMub_wins = 0
computer_wins = 0

while AdMub_wins < 2 and computer_wins < 2:
    print(f"AdMub Score:{AdMub_wins} computer Score:{computer_wins}")
    print("red.....")
    print("blue.....")
    print("green....")

    AdMub = input("AdMub, play your card: ")
    rand_num = random.randint(0,2)
    if rand_num == 0:
        computer = "red"
    elif rand_num == 1:
        computer = "blue"
    else:
        computer = "green"
    print(f"computer plays {computer}")

    if AdMub == computer:
        print("Draws!") 
    elif AdMub == "red":
        if computer == "blue":
            print("AdMub wins!")
            AdMub_wins += 1
        else:
            print("AdMub wins!")
            AdMub_wins += 1
    elif AdMub == "blue":
        if computer == "green": 
            print("AdMub wins!")
            AdMub_wins += 1
        else:
            print("computer wins!")
            computer_wins += 1
    elif AdMub == "green": 
        if computer == "blue": 
            print("computer wins!")
            computer_wins += 1
        else: 
            print("computer wins!")
            computer_wins += 1
    else:
        print("Game-Over!")
# Out:
# AdMub Score:0 computer Score:0
# red.....
# blue.....
# green....
# AdMub, play your card: red
# computer plays red
# Draws!
# AdMub Score:0 computer Score:0
# red.....
# blue.....
# green....
# AdMub, play your card: red
# computer plays green
# AdMub wins!
# AdMub Score:1 computer Score:0
# red.....
# blue.....
# green....
# AdMub, play your card: blue
# computer plays blue
# Draws!
# AdMub Score:1 computer Score:0
# red.....
# blue.....
# green....
# AdMub, play your card: green
# computer plays red
# computer wins!
# AdMub Score:1 computer Score:1
# red.....
# blue.....
# green....
# AdMub, play your card: blue
# computer plays green
# AdMub wins!

# %%
import random
AdMub_wins = 0
computer_wins = 0

while AdMub_wins < 2 and computer_wins < 2:
    print(f"AdMub Score:{AdMub_wins} computer Score:{computer_wins}")
    print("red.....")
    print("blue.....")
    print("green....")

    AdMub = input("AdMub, play your card: ")
    rand_num = random.randint(0,2)
    if rand_num == 0:
        computer = "red"
    elif rand_num == 1:
        computer = "blue"
    else:
        computer = "green"
    print(f"computer plays {computer}")

    if AdMub == computer:
        print("Draws!") 
    elif AdMub == "red":
        if computer == "blue":
            print("AdMub wins!")
            AdMub_wins += 1
        else:
            print("AdMub wins!")
            AdMub_wins += 1
    elif AdMub == "blue":
        if computer == "green": 
            print("AdMub wins!")
            AdMub_wins += 1
        else:
            print("computer wins!")
            computer_wins += 1
    elif AdMub == "green": 
        if computer == "blue": 
            print("computer wins!")
            computer_wins += 1
        else: 
            print("computer wins!")
            computer_wins += 1
    else:
        print("Game-Over!")
# Out:
# AdMub Score:0 computer Score:0
# red.....
# blue.....
# green....
# AdMub, play your card: yellow
# computer plays red
# Game-Over!
# AdMub Score:0 computer Score:0
# red.....
# blue.....
# green....
# AdMub, play your card: red
# computer plays red
# Draws!
# AdMub Score:0 computer Score:0
# red.....
# blue.....
# green....
# AdMub, play your card: red
# computer plays green
# AdMub wins!
# AdMub Score:1 computer Score:0
# red.....
# blue.....
# green....
# AdMub, play your card: red
# computer plays blue
# AdMub wins!

# %%
import random
AdMub_wins = 0
computer_wins = 0

while AdMub_wins < 2 and computer_wins < 2:
    print(f"AdMub Score:{AdMub_wins} computer Score:{computer_wins}")
    print("red.....")
    print("blue.....")
    print("green....")

    AdMub = input("AdMub, play your card: ").lower()
    rand_num = random.randint(0,2)
    if rand_num == 0:
        computer = "red"
    elif rand_num == 1:
        computer = "blue"
    else:
        computer = "green"
    print(f"computer plays {computer}")

    if AdMub == computer:
        print("Draws!") 
    elif AdMub == "red":
        if computer == "blue":
            print("AdMub wins!")
            AdMub_wins += 1
        else:
            print("AdMub wins!")
            AdMub_wins += 1
    elif AdMub == "blue":
        if computer == "green": 
            print("AdMub wins!")
            AdMub_wins += 1
        else:
            print("computer wins!")
            computer_wins += 1
    elif AdMub == "green": 
        if computer == "blue": 
            print("computer wins!")
            computer_wins += 1
        else: 
            print("computer wins!")
            computer_wins += 1
    else:
        print("Please,enter a valid game!")
# Out:
# AdMub Score:0 computer Score:0
# red.....
# blue.....
# green....
# AdMub, play your card: red
# computer plays green
# AdMub wins!
# AdMub Score:1 computer Score:0
# red.....
# blue.....
# green....
# AdMub, play your card: red
# computer plays red
# Draws!
# AdMub Score:1 computer Score:0
# red.....
# blue.....
# green....
# AdMub, play your card: green
# computer plays blue
# computer wins!
# AdMub Score:1 computer Score:1
# red.....
# blue.....
# green....
# AdMub, play your card: red
# computer plays blue
# AdMub wins!

# %%
import random
AdMub_wins = 0
computer_wins = 0

while AdMub_wins < 2 and computer_wins < 2:
    print(f"AdMub Score:{AdMub_wins} computer Score:{computer_wins}")
    print("red.....")
    print("blue.....")
    print("green....")

    AdMub = input("AdMub, play your card: ").lower()
    rand_num = random.randint(0,2)
    if rand_num == 0:
        computer = "red"
    elif rand_num == 1:
        computer = "blue"
    else:
        computer = "green"
    print(f"computer plays {computer}")

    if AdMub == computer:
        print("Draws!") 
    elif AdMub == "red":
        if computer == "blue":
            print("AdMub wins!")
            AdMub_wins += 1
        else:
            print("AdMub wins!")
            AdMub_wins += 1
    elif AdMub == "blue":
        if computer == "green": 
            print("AdMub wins!")
            AdMub_wins += 1
        else:
            print("computer wins!")
            computer_wins += 1
    elif AdMub == "green": 
        if computer == "blue": 
            print("computer wins!")
            computer_wins += 1
        else: 
            print("computer wins!")
            computer_wins += 1
    else:
        print("Please,enter a valid game!")
    
print(f"FINAL SCORE...... AdMub:{AdMub_wins} computer:{computer_wins}")
# Out:
# AdMub Score:0 computer Score:0
# red.....
# blue.....
# green....
# AdMub, play your card: red
# computer plays blue
# AdMub wins!
# AdMub Score:1 computer Score:0
# red.....
# blue.....
# green....
# AdMub, play your card: red
# computer plays green
# AdMub wins!
# FINAL SCORE...... AdMub:2 computer:0

# %%
import random
AdMub_wins = 0
computer_wins = 0

while AdMub_wins < 2 and computer_wins < 2:
    print(f"AdMub Score:{AdMub_wins} computer Score:{computer_wins}")
    print("red.....")
    print("blue.....")
    print("green....")

    AdMub = input("AdMub, play your card: ").lower()
    rand_num = random.randint(0,2)
    if rand_num == 0:
        computer = "red"
    elif rand_num == 1:
        computer = "blue"
    else:
        computer = "green"
    print(f"computer plays {computer}")

    if AdMub == computer:
        print("Draws!") 
    elif AdMub == "red":
        if computer == "blue":
            print("AdMub wins!")
            AdMub_wins += 1
        else:
            print("AdMub wins!")
            AdMub_wins += 1
    elif AdMub == "blue":
        if computer == "green": 
            print("AdMub wins!")
            AdMub_wins += 1
        else:
            print("computer wins!")
            computer_wins += 1
    elif AdMub == "green": 
        if computer == "blue": 
            print("computer wins!")
            computer_wins += 1
        else: 
            print("computer wins!")
            computer_wins += 1
    else:
        print("Please,enter a valid game!")
print(f"FINAL SCORE:  AdMub....{AdMub_wins}  computer.....{computer_wins}")
# Out:
# AdMub Score:0 computer Score:0
# red.....
# blue.....
# green....
# AdMub, play your card: red
# computer plays green
# AdMub wins!
# AdMub Score:1 computer Score:0
# red.....
# blue.....
# green....
# AdMub, play your card: red
# computer plays blue
# AdMub wins!
# FINAL SCORE:  AdMub....2  computer.....0

# %%
import random
AdMub_wins = 0
computer_wins = 0
winning_score = 3
while AdMub_wins < winning_score and computer_wins < winning_score:
    print(f"AdMub Score:{AdMub_wins} computer Score:{computer_wins}")
    print("red.....")
    print("blue.....")
    print("green....")

    AdMub = input("AdMub, play your card: ").lower()
    rand_num = random.randint(0,2)
    if rand_num == 0:
        computer = "red"
    elif rand_num == 1:
        computer = "blue"
    else:
        computer = "green"
    print(f"computer plays {computer}")

    if AdMub == computer:
        print("Draws!") 
    elif AdMub == "red":
        if computer == "blue":
            print("AdMub wins!")
            AdMub_wins += 1
        else:
            print("AdMub wins!")
            AdMub_wins += 1
    elif AdMub == "blue":
        if computer == "green": 
            print("AdMub wins!")
            AdMub_wins += 1
        else:
            print("computer wins!")
            computer_wins += 1
    elif AdMub == "green": 
        if computer == "blue": 
            print("computer wins!")
            computer_wins += 1
        else: 
            print("computer wins!")
            computer_wins += 1
    else:
        print("Please,enter a valid game!")
if AdMub_wins > computer_wins:
    print("Congrats, You won!!")
else:
    print("You lost!!")
print(f"FINAL SCORE:  AdMub....{AdMub_wins}  computer.....{computer_wins}")
# Out:
# AdMub Score:0 computer Score:0
# red.....
# blue.....
# green....
# AdMub, play your card: red
# computer plays red
# Draws!
# AdMub Score:0 computer Score:0
# red.....
# blue.....
# green....
# AdMub, play your card: red
# computer plays green
# AdMub wins!
# AdMub Score:1 computer Score:0
# red.....
# blue.....
# green....
# AdMub, play your card: lue
# computer plays blue
# Please,enter a valid game!
# AdMub Score:1 computer Score:0
# red.....
# blue.....
# green....
# AdMub, play your card: lue
# computer plays red
# Please,enter a valid game!
# AdMub Score:1 computer Score:0
# red.....
# blue.....
# green....
# AdMub, play your card: blue
# computer plays red
# computer wins!
# AdMub Score:1 computer Score:1
# red.....
# blue.....
# green....
# AdMub, play your card: green
# computer plays red
# computer wins!
# AdMub Score:1 computer Score:2
# red.....
# blue.....
# green....
# AdMub, play your card: red
# computer plays green
# AdMub wins!
# AdMub Score:2 computer Score:2
# ...

# %%
import random
AdMub_wins = 0
computer_wins = 0
winning_score = 3
while AdMub_wins < winning_score and computer_wins < winning_score:
    print(f"AdMub Score:{AdMub_wins} computer Score:{computer_wins}")
    print("red.....")
    print("blue.....")
    print("green....")

    AdMub = input("AdMub, play your card: ").lower()
    if AdMub == "quit" or AdMub == "q":
        break
    rand_num = random.randint(0,2)
    if rand_num == 0:
        computer = "red"
    elif rand_num == 1:
        computer = "blue"
    else:
        computer = "green"
    print(f"computer plays {computer}")

    if AdMub == computer:
        print("Draws!") 
    elif AdMub == "red":
        if computer == "blue":
            print("AdMub wins!")
            AdMub_wins += 1
        else:
            print("AdMub wins!")
            AdMub_wins += 1
    elif AdMub == "blue":
        if computer == "green": 
            print("AdMub wins!")
            AdMub_wins += 1
        else:
            print("computer wins!")
            computer_wins += 1
    elif AdMub == "green": 
        if computer == "blue": 
            print("computer wins!")
            computer_wins += 1
        else: 
            print("computer wins!")
            computer_wins += 1
    else:
        print("Please,enter a valid game!")
if AdMub_wins > computer_wins:
    print("Congrats, You won!!")
else:
    print("You lost!!")
print(f"FINAL SCORE:  AdMub....{AdMub_wins}  computer.....{computer_wins}")
# Out:
# AdMub Score:0 computer Score:0
# red.....
# blue.....
# green....
# AdMub, play your card: red
# computer plays blue
# AdMub wins!
# AdMub Score:1 computer Score:0
# red.....
# blue.....
# green....
# AdMub, play your card: jj
# computer plays red
# Please,enter a valid game!
# AdMub Score:1 computer Score:0
# red.....
# blue.....
# green....
# AdMub, play your card: q
# Congrats, You won!!
# FINAL SCORE:  AdMub....1  computer.....0

# %%
import random
AdMub_wins = 0
computer_wins = 0
winning_score = 3
while AdMub_wins < winning_score and computer_wins < winning_score:
    print(f"AdMub Score:{AdMub_wins} computer Score:{computer_wins}")
    print("red.....")
    print("blue.....")
    print("green....")

    AdMub = input("AdMub, play your card: ").lower()
    if AdMub == "quit" or AdMub == "q":
        break
    rand_num = random.randint(0,2)
    if rand_num == 0:
        computer = "red"
    elif rand_num == 1:
        computer = "blue"
    else:
        computer = "green"
    print(f"computer plays {computer}")

    if AdMub == computer:
        print("Draws!") 
    elif AdMub == "red":
        if computer == "blue":
            print("AdMub wins!")
            AdMub_wins += 1
        else:
            print("AdMub wins!")
            AdMub_wins += 1
    elif AdMub == "blue":
        if computer == "green": 
            print("AdMub wins!")
            AdMub_wins += 1
        else:
            print("computer wins!")
            computer_wins += 1
    elif AdMub == "green": 
        if computer == "blue": 
            print("computer wins!")
            computer_wins += 1
        else: 
            print("computer wins!")
            computer_wins += 1
    else:
        print("Please,enter a valid game!")
if AdMub_wins > computer_wins:
    print("Congrats, You won!!")
else:
    print("You lost!!")
print(f"FINAL SCORE:  AdMub....{AdMub_wins}  computer.....{computer_wins}")
# Out:
# AdMub Score:0 computer Score:0
# red.....
# blue.....
# green....
# AdMub, play your card: red
# computer plays red
# Draws!
# AdMub Score:0 computer Score:0
# red.....
# blue.....
# green....
# AdMub, play your card: blue
# computer plays red
# computer wins!
# AdMub Score:0 computer Score:1
# red.....
# blue.....
# green....
# AdMub, play your card: red
# computer plays red
# Draws!
# AdMub Score:0 computer Score:1
# red.....
# blue.....
# green....
# AdMub, play your card: red
# computer plays red
# Draws!
# AdMub Score:0 computer Score:1
# red.....
# blue.....
# green....
# AdMub, play your card: red
# computer plays red
# Draws!
# AdMub Score:0 computer Score:1
# red.....
# blue.....
# green....
# AdMub, play your card: green
# computer plays green
# Draws!
# AdMub Score:0 computer Score:1
# red.....
# blue.....
# green....
# AdMub, play your card: red
# computer plays green
# AdMub wins!
# AdMub Score:1 computer Score:1
# red.....
# blue.....
# green....
# ...

# %%
import random
AdMub_wins = 0
computer_wins = 0
winning_score = 3
while AdMub_wins < winning_score and computer_wins < winning_score:
    print(f"AdMub Score:{AdMub_wins} computer Score:{computer_wins}")
    print("red.....")
    print("blue.....")
    print("green....")

    AdMub = input("AdMub, play your card: ").lower()
    if AdMub == "quit" or AdMub == "q":
        break
    rand_num = random.randint(0,2)
    if rand_num == 0:
        computer = "red"
    elif rand_num == 1:
        computer = "blue"
    else:
        computer = "green"
    print(f"computer plays {computer}")

    if AdMub == computer:
        print("Draws!") 
    elif AdMub == "red":
        if computer == "blue":
            print("AdMub wins!")
            AdMub_wins += 1
        else:
            print("AdMub wins!")
            AdMub_wins += 1
    elif AdMub == "blue":
        if computer == "green": 
            print("AdMub wins!")
            AdMub_wins += 1
        else:
            print("computer wins!")
            computer_wins += 1
    elif AdMub == "green": 
        if computer == "blue": 
            print("computer wins!")
            computer_wins += 1
        else: 
            print("computer wins!")
            computer_wins += 1
    else:
        print("Please,enter a valid game!")
if AdMub_wins > computer_wins:
    print("Congrats, You won!!")
elif AdMub_wins == computer_wins:
    print("Draws!!")
else:
    print("You lost!!")
print(f"FINAL SCORE:  AdMub....{AdMub_wins}  computer.....{computer_wins}")
# Out:
# AdMub Score:0 computer Score:0
# red.....
# blue.....
# green....
# AdMub, play your card: red
# computer plays red
# Draws!
# AdMub Score:0 computer Score:0
# red.....
# blue.....
# green....
# AdMub, play your card: blue
# computer plays green
# AdMub wins!
# AdMub Score:1 computer Score:0
# red.....
# blue.....
# green....
# AdMub, play your card: green
# computer plays blue
# computer wins!
# AdMub Score:1 computer Score:1
# red.....
# blue.....
# green....
# AdMub, play your card: quit
# Draws!!
# FINAL SCORE:  AdMub....1  computer.....1
